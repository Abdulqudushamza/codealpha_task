# %% [markdown]
# ***TASK 1***
#
# Use Python libraries such as BeautifulSoup or Scrapy to extract data from websites.
#
# Identify and collect relevant datasets from publicly available web pages.
#
# If you do not code, rely on automated web-scraping tools like Octoparse or ParseHub.
#
# Understand basic HTML structure and website navigation to gather accurate data.
#
# Build custom datasets tailored to specific research or analysis needs.

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.6 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
#!pip install -qq google_play_scraper
# !pip install -q transformers

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google_play_scraper import app, Sort, reviews_all
import plotly.express as px

# %%
# Reviews_all Scrape the reviewid, username, content etc from the app page into a JSON format
dataapp = reviews_all('com.dataappng',sleep_milliseconds=0, lang='en', country='NG', sort=Sort.NEWEST)

# %%
dataapp
# Out:
# [{'reviewId': 'f6ef6d49-ebfa-4e3e-8ddc-62a33d4c4402',
#   'userName': 'Agbeni Blessing',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLCwihWReyr_stMoBSc0LDbfbDGxN5blm36J03hGUbRqY-Fsw=mo',
#   'content': "this app they are thief I send 3k into my account I can't found the money anymore",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 11, 2, 16, 13, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '85b47540-b784-49d0-9e1d-db5ad7f48840',
#   'userName': 'Olanike Ayandeyi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIghl2LoKMeCQnulke1N8MZBdX1y_VK3If7in2_JGsFphhXaw=mo',
#   'content': "they are scammers run away from them. I funded d app the first time they didn't show it d second time it wasn't on d dashboard. Then I message their customer service and they started insulting me and my family because I log complain. very useless app doesn't use it",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0.3',
#   'at': datetime.datetime(2025, 10, 26, 20, 45, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.3'},
#  {'reviewId': 'fd468a10-2b6e-4f83-8808-d0d657373a8d',
#   'userName': 'Antibas Yakubu',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW8syRt5Ep9R6j9-zDGmf5lfwDBzi2xhMsDGH6kmdBzruRn3orc',
#   'content': "Your networking is bad, and it doesn't seem like you're even trying to resolve the issue. Even with tons of reviews, you never react, reply or try to do anything about those issues, that'll at least be noticed by the people complaining about their experiences and the insufficiency of the app performance. You charge customers when they try to update the app as well. Which sucks, and the action doesn't add up to the idea of how Professionality and honesty is defined.",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.3',
#   'at': datetime.datetime(2025, 10, 25, 17, 16, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.3'},
#  {'reviewId': '9a85b1e2-a9d0-4343-9ac4-b82414ff0359',
#   'userName': 'Joshua Mordi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVEbFspJmqtiB-y8AYpJLzxcbkkdfr_Ao_W_iMFhxuO83Ym0ke9',
#   'content': "since I upgraded this app I can't even login anymore... my money is inside and they wouldn't let me access it ... it's useless",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.3',
#   'at': datetime.datetime(2025, 10, 23, 10, 5, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.3'},
#  {'reviewId': '1bc93749-4060-4a51-9311-b645f17a111a',
#   'userName': 'Asainze Ernest',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUtUiBcux7skrAmfkpPzxjgVxD8Bue2zLx3fBu_pk4rfHhrMP49',
#   'content': 'Very poor application',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.3',
#   'at': datetime.datetime(2025, 10, 21, 6, 15, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.3'},
#  {'reviewId': 'b4807b2b-6608-45c7-bccf-e92790f69588',
#   'userName': 'Hillary Kanayo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKgIysd1n4sbAyZm8OQUEKs2Kln_2NVQB-5hkcm9nmPAOllcA=mo',
#   'content': 'I love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.2',
#   'at': datetime.datetime(2025, 10, 21, 5, 50, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.2'},
#  {'reviewId': 'a530b578-7e29-4d91-a6e4-b1cab20142d5',
#   'userName': 'taiwo Atanda taiwo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLBhqtLSQIlJd33gEeas1dJwgYbPf8SyYY8wjgXX3oL9mNq1w=mo',
#   'content': 'excellent kudos to you guys 👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.2',
#   'at': datetime.datetime(2025, 10, 20, 20, 5, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.2'},
#  {'reviewId': 'abab2615-bab7-49c8-b7af-1e2345b533a4',
#   'userName': 'Fly Kid',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ6FSQcjGoObWKX_ju5UESICi9A5CFtSKYh-TYl_Z3jmvuhLA=mo',
#   'content': "this app is the most useless app I ever seen I just updated it now I can't long in my money is gone this app is a scam",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.2',
#   'at': datetime.datetime(2025, 10, 19, 12, 55, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.2'},
#  {'reviewId': '60651594-776d-4fc0-b522-a241977f55f5',
#   'userName': 'Ibukun Adepoju',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJVUgUeYMHE_jvkmRcfh6iDFNRuO55rlrVTueiz1Ogp_h2fRw=mo',
#   'content': "you guys are thief. I put in 1000 naira to my account and immediately I updated una nonsense app you removed my money can't find it inside my account. fraudulent app. stay away from this app called DataApp they will thief your funds once you updated their nonsense app. e no go better for una",
#   'score': 1,
#   'thumbsUpCount': 15,
#   'reviewCreatedVersion': '1.0.2',
#   'at': datetime.datetime(2025, 10, 18, 9, 10, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.2'},
#  {'reviewId': 'a18d0511-41c4-4f0e-905a-598eae3acc0e',
#   'userName': 'Jamilu Musa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKRVrGXnIi2aKJWO4sS1YQCVmZkfXZTL0HC4B52rIcqvf3iZQ=mo',
#   'content': 'Good job',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 10, 11, 20, 22, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '5ed385f1-753b-4741-b62c-e987848b1cf8',
#   'userName': 'Joy Okoh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIfSLKka_VvXLxFF95y1cyNBufnyey_RXavg9pvnwWZsKNvlQ=mo',
#   'content': "I top up money in the app now i can't login again my money is gone",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 10, 10, 10, 53, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '020df767-161d-49f4-8682-a513216e4d06',
#   'userName': 'Rabiu Suleiman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVnicIOUtRSskOkRlRrVWoRExuVrIO2y1Ix3fgkbPNQr6QUEtmq',
#   'content': 'careful. I tried top up and my money is gone. almost a week no reversal and no way to get in touch with them.',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 9, 30, 8, 16, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'afc0bc35-06cf-4c1d-a843-a0cd9eeaac0c',
#   'userName': 'Younghally Hally',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL-RMoJYroSIWKLidLH8IbdSj6nn0KhgCCHqJh4c7l9YHDrgQ=mo',
#   'content': "this app is scam it really frustrating I sent money to the account they gave me as their wallet I didn't receive the money",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 9, 26, 11, 35, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'ea7c28e3-8e42-4673-be55-f7bd93b6b82e',
#   'userName': 'Yushau kabiru',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXdphw33wu_TI7iSWtKfJ91tSmwwgxo6G94RUcsZGH5dVpOFP1u',
#   'content': 'my app no gree upon',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 9, 19, 13, 27, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '08a44ec8-2716-4045-bc66-b7d8cf37ffdf',
#   'userName': 'Nasiru Mariam',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIftZ48U_5-h68aCKxeq7s_oWaiLyuTlxbrCq3GOkmxPblHmg=mo',
#   'content': 'abeg solve this issue I want to do data now and Airtel is not bringing any options why other networks are abeg solve I need data urgently',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 9, 16, 16, 40, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'eca9ef74-4719-4628-8084-4725924117d4',
#   'userName': 'Blessing Olaitan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKvUG3Ej7VFSJ38oilAhPUwiQt-9OTJViuGS08Qj6bi2QUWnQ=mo',
#   'content': "This app is very useless, I had a pending transaction and they refused to resolve the issue and mind you, nothing like live support. It's indeed a scam, they probably bought those good reviews. @platstore take note,they are using this app to scam people, remove it!!!!",
#   'score': 1,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 9, 4, 10, 8, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'd05ae0e7-6f9f-4ff2-90b7-c26288fd7647',
#   'userName': 'Moses Taiwo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVuWZxlmSGlqp6KAH7iCaFPX634caczrnoVNKArQLl9wcexYuhQ',
#   'content': 'This data app is useless i just pay 5000 to it now and i mistakely log out, and this useless app did not allow me to login to the app again am really disappointed what a nonsense app',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 8, 25, 6, 28, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '15bd980c-a0c3-405b-a4b1-c0454bc9b600',
#   'userName': "God's will Ogbor",
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLXLbWsKiK9ay9hq4RUn4Ipm9WePrMHGwUW1MjonNADLOdi5w=mo',
#   'content': "it always shows unsuccessful whenever I try to buy data. I can't even withdraw my own money. it's so frustrating. Download at your own risk",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 8, 10, 9, 50, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '5e698f04-dd7f-4e5f-b341-2047c4c4ef72',
#   'userName': 'Oghene wede',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL4UPzcGArd-kT9AwYc3gezhTuaj3VQLfoV7XF5zSkxogOLsQ=mo',
#   'content': 'the app is fake your data will be pending 😓😠😠😡',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 7, 31, 20, 31, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '6c8a685a-4608-4344-8f33-4fdad1a2eaed',
#   'userName': 'DataApp Limited',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVF1z3OVsWxuAKZIA_rJGixkaHlikOZLvClLvVw7UAzguVfdl4',
#   'content': '🎉❤️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 7, 30, 0, 18, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '937274ae-bc76-4f63-a7f1-7717626c32c1',
#   'userName': 'Morakinyo Oluwaseun',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUaTtCMVRJ4c2c3dTqc-wuZZtU36f3tI0vxk2AQ23J-MUmjF10',
#   'content': 'please I have account on this app is not open please help me',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 7, 19, 16, 25, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '01c4a88a-ef22-4e23-9804-5b00bca6b8a6',
#   'userName': 'uche okafor',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI2Qnigkg2lM-QcFgn_EJ4qFyAwCE9swQV9JzL1uVn_N3wOkg=mo',
#   'content': "I love the app but when I have an incomplete pending transaction there's no one to run to, the live support on whatup never responds.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 5, 19, 19, 58, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '54af89b1-6ce6-4600-b3df-8cd8cec84f2c',
#   'userName': 'Badmus Hibrahim',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIcjKTe81aKE1o-YlOnn1vrmTMm-41zS-7OT5GcaN84fU40mg=mo',
#   'content': 'I love this app',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 4, 28, 7, 36, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'b2d032d5-1d26-47e2-ad64-2fe286d7a6a4',
#   'userName': 'Amnet Plug',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW5KmQWUDoLwFtoH6OVg3ykukbF7RZajc3_rW39nPSmVZ7DMcM',
#   'content': '❤️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 4, 11, 1, 26, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '040c5026-a15f-4a8e-8d9c-79e275c9fc56',
#   'userName': 'Kabiru Sulaiman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXTLAn4HGH0L3kX6kMxxGbeSBoo4wnh2c4uo0UTVwtj_JZevws',
#   'content': 'we Love Dataapp',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 3, 30, 18, 11, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '251b3ffa-2a74-4ea6-a20b-6cd3c4787ca8',
#   'userName': 'Lawal Rachael Aina',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXVstTI5h-ryq5neZfepbyhsR2YlHYRHM203K5yC56UaxyTjlVD',
#   'content': 'Good app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 3, 12, 15, 24, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '9d1fdc21-eda2-4e42-80cf-018f86e7a933',
#   'userName': 'Musa Tukur',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX7THXlq-xhMOlxqDD6jkojaxnW-FWgx93LpC1pFdQU5KpJSjV9',
#   'content': 'Data is the best App Ever They Data price is Good and very fast, if I can Give them 7 Stars I will give them ✔️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 3, 12, 2, 47, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '68c7baab-253b-49c0-b84b-21ece0dc9d99',
#   'userName': 'Zubairu Mohammed',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXuXHa5j5EpXoB3yK48qnARinLE0kWCxX0Ei9f5NnpwVSpQ-S3x',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 3, 1, 21, 57, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '33481431-c0a8-47ea-a9ad-949fe596ec40',
#   'userName': 'Tofunmi Alake',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI0BcaGOzkCkVJgehfaSVEJCRrJCQd6NYVyLCWo1OC9cJ_7kA=mo',
#   'content': "This app is not reliable i'have sent money there since last week and I have not been credited I wish i can give it zero star",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 26, 17, 44, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '3227ca62-8e7e-4dcf-bfe0-b828022f9d4d',
#   'userName': 'oladele surprise',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKb1Z6SLukAchmvbTOOF4MxuRTBrQERclSs463BWs-c-y2uwA=mo',
#   'content': "At first it was good buh suddenly thier network scrambled, I funded my wallet buh it's not reflecting. The thing is so frustrating,they should really do something about it.",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 26, 11, 53, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'e1bc76e8-deb9-434e-8a37-5cf41e963b45',
#   'userName': 'Bella Onyeka',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW2X5Vdsw1tzdUoQhggw7olN6Dal4PrBnA5jiYTcRgz-k7PdIbw',
#   'content': "Hope you're seeing all the bad reviews before You decide to download this useless scam app. Don't download it, they are scam I have confirmed myself. No customer service support. They can't let You withdraw out your money. Your data dosen't get into your phone. You are debited more than the amount of data You bought. If you forgot your password to log in, just forget about that particular account. It's a big ZERO star And notice the only positive reviews are from the Hausas. Tread with caution.",
#   'score': 1,
#   'thumbsUpCount': 21,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 26, 8, 16, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '4c45586d-68ea-478e-aeb4-3c674cc54847',
#   'userName': 'Akange Samuel Sesugh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ48hrzSU4XMYAVNcHccGTYK5qYm1HgnMAQIQE3PSQvW8xXWg=mo',
#   'content': "This data app is becoming a failure and an app I've regret using so far,their services is not good at all,I've sent money up to three times without receiving it and without a refund,I'm begining to think they are thieves.",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 26, 5, 43, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '992573bb-b467-43b8-b5cb-7024c384564d',
#   'userName': 'Muna David',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJcBd0R-3KHYpPvuV_CEC6hcDAI2oJeHV-FoIKknP2umUSsDA=mo',
#   'content': 'Terrible',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 25, 6, 52, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '55f6ebd5-05f3-486e-a7a3-5bb992998c3b',
#   'userName': 'Adekanye Adedayo (Richy Crown)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWTYKyWbF04Mt0DRfXXAxvWdaKAe5kQEyRJBfd8jG-Bvt9VqmI',
#   'content': 'Please remove this app from playstore The owner said it is faked',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 21, 8, 51, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '75e80046-7631-4bd0-94de-1a6fd159b024',
#   'userName': 'uzor ekwueme',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL3dhSPt2XD1q67pXfAJJ41AB5SEFDXByf3KCo5UxmEoD0ajA=mo',
#   'content': "What's the data limits for the day since it's for business?",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 19, 13, 14, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'c3e64c24-02c9-490d-89d6-ce5b19799957',
#   'userName': 'David Oben',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUCe0_iFjUyelNEHTS8JtoXdA1xslP88L1win4MgaZmDdwRjuaL',
#   'content': 'I really really love the app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 17, 22, 32, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '94dc0bcc-86b2-4b5d-9e49-5eeb68076805',
#   'userName': 'Muslim Abubakar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIuv0W9VomEZEbq4JnewQHDBJNHP8iK9OcTv6uFOQGM2HqfAg=mo',
#   'content': 'Thank you Dataapp❤️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 15, 14, 26, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'c2fd92dd-5950-4263-b5e4-697223f213ef',
#   'userName': 'DINERO BTC',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX_NZgsJKU0-_5R8wHoeN5dMjzgVUtYIntjag4-vk8e1LdjqEEG',
#   'content': 'So lovely 😍🌹..but my money as been pending',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 13, 17, 25, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '2384aed5-b0ec-47c6-a6b7-77806a3aaa78',
#   'userName': 'Godswill Okorie',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLdOCqrgMa0fuBgxTmCT9Mh9L_nVmDQeSzsIQCGnz9R5IpxXg=mo',
#   'content': 'DATAAPP FOR LIFE 💘💘💘',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 2, 8, 20, 58, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '0863e1e8-24a7-4796-bd67-6015dd91b58f',
#   'userName': 'Kifayat Babalola',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKL86He5LC1OIF8DyJDe5gISjw6Dk1dIY_vcEeepSVVPRWycw=mo',
#   'content': 'Good app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 7, 20, 47, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '5e0685b6-f871-4d43-b188-464bcd571348',
#   'userName': 'Hafizu yakubu Yusif',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXtYNhT9p39LEc_qYFdVJtYyLNRodmbdl3gEF-GIy91MJwXcv8',
#   'content': 'masha allah',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 2, 2, 10, 40, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '67153025-dd42-4f98-9172-fc72479cec2c',
#   'userName': 'Avdollah Muktar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK4VHWZ-RCyUIfYChzkZw9YjfWcPHUS3slPMw4KKyjKI30EKQ=mo',
#   'content': 'I Love Dataapp have best network stable and Good Customer care Thank you Dataapp',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 2, 1, 20, 33, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '7134a68d-840a-4732-a41c-a690c3536821',
#   'userName': 'GLORIOUS Skill',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKRBkiN__NuiUnxE0mSxOHQrZx6Ap2dlEHT2oi1QGRGCvUyIg=mo',
#   'content': 'How can I withdraw my money',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 31, 2, 48, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'daee2e2f-4c9d-476e-b297-c818fa1a478a',
#   'userName': 'michael Tarvihi Aondovenda',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ7asx_zexc0UaT0a8XYTeh8dcD1j7MPGZTF8K5kTIYRq1VEw=mo',
#   'content': "I wish i can give it zero star. You will transfer money into the app but you will never received it even when it happens to enter and you buy data they won't send data to you. Their support doesn't respond to messages. The app is just wack i end up losing my money.",
#   'score': 1,
#   'thumbsUpCount': 84,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 30, 10, 50, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '41a72907-eb61-4141-986f-e9c738d3a44d',
#   'userName': 'Salihu Nuhu ligyara',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL79nWdeJcuOR7qCOMuOG2ALEvPtbJyt_mAhnqHxwDa-rx5bg=mo',
#   'content': 'I feel be pilling joy',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 24, 22, 27, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '204eb97b-e306-4435-9bcf-7675db32ce2e',
#   'userName': 'Abdul rahman Saleh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ3X47gVDDgbmT8CptUYb_CSzAvp8FGDyI8SGGuI0hcljUslw=mo',
#   'content': 'The app is very fast in network',
#   'score': 2,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 23, 19, 48, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'eeebdac2-8454-43a3-8db5-f63718363143',
#   'userName': 'Mivanyi Gideon Chunga',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU82_LuU3yFNOmhl2OP7qD0Vcbm2CU0r_6lrU7WiXVVcy9i9Js',
#   'content': 'Very poor in resolve issues and customer service support. I hoped God save you when you had an error in transaction issues with the company.',
#   'score': 1,
#   'thumbsUpCount': 16,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 14, 15, 31, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '63bcb181-16f2-41d2-8a25-78051b1ce5fe',
#   'userName': 'Abbas ayuba Isah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVQmCgJTtCNhTrRALL_qoKPCfHug0Y2ap7Xn78KD94H3R_HXpo',
#   'content': 'Very nice app',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 13, 20, 16, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'ca7fabb9-a461-4c34-a42f-83cb3bda4f07',
#   'userName': 'Chinedu Nnaka',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLdZNFvE5KSfnau7IzWvlJ6StVnZ9NPyjyUlQlhbAIazn4zwQ=mo',
#   'content': "the app does not pay attention to customers I funded my wallet since yesterday but it hasn't reflected I complained about that but no reply was gotten",
#   'score': 1,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 1, 11, 10, 45, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '3baa0d6c-82fb-494f-ae63-6ee5b7899aaa',
#   'userName': 'Victor Ocheje',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLeBmzFypQHMf2NTUT4zXrJHLSZTSNXUJAl1umrZwAUwwg9SQ=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 11, 10, 41, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '902cbdd5-22ad-4b37-a51f-4432123a4f2a',
#   'userName': 'Kamal Umar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLOP65Q22KIgLccWt8MuaN-yLWACA39PC3yJYBm9-TCKqFEPw=mo',
#   'content': "Very rubbish app every it's having problem gof forbid I can't even login I just sent money into my account I can't even login the account again a scam app",
#   'score': 1,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 10, 16, 15, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '51252f49-b2a7-4c3c-9b31-1a1925736fa2',
#   'userName': 'isbajaa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLp_l8hXxBeRtmPBGkkA0ZvDgP8C9rTgfyZZOXEPoD4MpV2vA=mo',
#   'content': 'Reliability and standards',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2025, 1, 9, 22, 20, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '686eef13-d9a0-401c-a551-c9e70cde22ed',
#   'userName': 'solomon noble',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVjhEvocAR6kmwM4iYCtrmVW4UkcOrKWRFtxkYi6gosBtLyziY',
#   'content': 'I funded my wallet It did not reflect and also using the app is an issue',
#   'score': 1,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 6, 6, 40, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '19ae8c3c-96ff-4dfc-976c-6e146bc6f1fd',
#   'userName': 'Muhammad Yahaya Ibrahim',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWi0m0AbsvboXx4X-lUU02_jPXcHHtdtPtmHXhwoHZ15A-gyd2A',
#   'content': "The app.has no concern for it's customer,I happen to forget my transaction pin and failed to remember hence decide to change to new one.Up to the time of writing this they remain adamant",
#   'score': 1,
#   'thumbsUpCount': 14,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2025, 1, 3, 14, 34, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'd129e9fe-68a9-4ab9-a9b2-9765e105b2a2',
#   'userName': 'Godswill Okorie',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJVds-SSbFVCVZz_5LplO7irJ81z2EvytgTINh-AXHoghkXrQ=mo',
#   'content': "This is tue only place i have seen the cheapest data ever, i have tried many apps but this is exceptional cheapest data reliable and perfect customer care... Many things in this app, just try ane see. Words can't express how i feel about this app. The best among the bests",
#   'score': 5,
#   'thumbsUpCount': 59,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2024, 12, 2, 6, 4, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': 'bc4bb75c-fa28-45d6-a84c-b07fd4ef988e',
#   'userName': 'Victor Isaiah',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKvC3l5Dc7VK4doyt2m9cx0wAMGYVt2VXxGNxDlLVaWhTSOeA=mo',
#   'content': 'App seems to rug ppls of its funds, they give u an account to fund and wen you do you wont get funded in the app and it always has network issues....fix your app',
#   'score': 1,
#   'thumbsUpCount': 13,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2024, 11, 29, 21, 35, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '84d07e48-eb21-4fb7-a0d7-09343bd414dd',
#   'userName': 'NURA LAWAL',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVuWvmvRF9KnozGJF8m1Ctc9mW9zYyQ3JW1PzOmb-eQGextUl0Y',
#   'content': 'I have downloaded the app but I find it hard to see ware about my vetual account ware can I have it',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2024, 11, 29, 9, 6, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '07aed132-89d7-48eb-8431-40ac3a4b4305',
#   'userName': 'Abba Nasir',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJSs7voEl1kusDR5gb83EgBsj8ueo_6XHLsnNKqQhibKkMuRg=mo',
#   'content': 'Data is good',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 11, 4, 12, 32, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '20762a82-026b-41e2-893a-196fcd0c9f43',
#   'userName': 'Bello Abdullahi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVZ4P79eqQJkokPS968lHyFE76szSVAwkmjczF-aJv8pfGStaKO',
#   'content': 'Convenient and Reliable! DataApp has made life so much easier, I can buy data, airtime, and even pay my bills all in one place. The app is super fast nd everything is just a few taps away. Highly recommend it to anyone looking for a quick nd convenient solution 👍',
#   'score': 5,
#   'thumbsUpCount': 71,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2024, 11, 3, 2, 14, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '38389945-88e9-4a68-870d-5a7f35e4958e',
#   'userName': 'Abba Yakubu',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocITMAujtGnzU4V9m0IfAsusrPcngrUtih9To7cV5_WRi6oV6A=mo',
#   'content': 'We Love DataApp',
#   'score': 5,
#   'thumbsUpCount': 16,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2024, 11, 2, 19, 29, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'},
#  {'reviewId': '27f7b05f-6c4d-4e80-a78e-78d4568e9c01',
#   'userName': "Abba Shu'aibu",
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLQanBfTqLdcSJeSqM7GXBiJgN_Ou9pJNr6WGUepX_f0Ty33g=mo',
#   'content': 'Very Good👍',
#   'score': 5,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '1.0.0',
#   'at': datetime.datetime(2024, 11, 2, 19, 27, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0.0'}]

# %%
# convert the json data into a dataframe
dataapp_df = pd.json_normalize(dataapp)

# %%
dataapp_df
# Out:
#                                 reviewId          userName  \
# 0   f6ef6d49-ebfa-4e3e-8ddc-62a33d4c4402   Agbeni Blessing
# 1   85b47540-b784-49d0-9e1d-db5ad7f48840  Olanike Ayandeyi
# 2   fd468a10-2b6e-4f83-8808-d0d657373a8d    Antibas Yakubu
# 3   9a85b1e2-a9d0-4343-9ac4-b82414ff0359      Joshua Mordi
# 4   1bc93749-4060-4a51-9311-b645f17a111a    Asainze Ernest
# ..                                   ...               ...
# 56  84d07e48-eb21-4fb7-a0d7-09343bd414dd        NURA LAWAL
# 57  07aed132-89d7-48eb-8431-40ac3a4b4305        Abba Nasir
# 58  20762a82-026b-41e2-893a-196fcd0c9f43   Bello Abdullahi
# 59  38389945-88e9-4a68-870d-5a7f35e4958e       Abba Yakubu
# 60  27f7b05f-6c4d-4e80-a78e-78d4568e9c01     Abba Shu'aibu
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a/ACg8oc...
# 1   https://play-lh.googleusercontent.com/a/ACg8oc...
# 2   https://play-lh.googleusercontent.com/a-/ALV-U...
# 3   https://play-lh.googleusercontent.com/a-/ALV-U...
# 4   https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                ...
# 56  https://play-lh.googleusercontent.com/a-/ALV-U...
# 57  https://play-lh.googleusercontent.com/a/ACg8oc...
# 58  https://play-lh.googleusercontent.com/a-/ALV-U...
# 59  https://play-lh.googleusercontent.com/a/ACg8oc...
# 60  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                               content  score  thumbsUpCount  \
# 0   this app they are thief I send 3k into my acco...      1              0
# 1   they are scammers run away from them. I funded...      1              3
# 2   Your networking is bad, and it doesn't seem li...      2              0
# 3   since I upgraded this app I can't even login a...      1              0
# 4                               Very poor application      1              0
# ..                                                ...    ...            ...
# 56  I have downloaded the app but I find it hard t...      1              7
# 57                                       Data is good      5              4
# 58  Convenient and Reliable! DataApp has made life...      5             71
# 59                                    We Love DataApp      5             16
# 60                                         Very Good👍      5              8
#
#    reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                 1.0.0 2025-11-02 16:13:04         None      None      1.0.0
# 1                 1.0.3 2025-10-26 20:45:41         None      None      1.0.3
# 2                 1.0.3 2025-10-25 17:16:23         None      None      1.0.3
# 3                 1.0.3 2025-10-23 10:05:53         None      None      1.0.3
# 4                 1.0.3 2025-10-21 06:15:56         None      None      1.0.3
# ..                  ...                 ...          ...       ...        ...
# 56                1.0.0 2024-11-29 09:06:05         None      None      1.0.0
# 57                 None 2024-11-04 12:32:41         None      None       None
# 58                1.0.0 2024-11-03 02:14:09         None      None      1.0.0
# 59                1.0.0 2024-11-02 19:29:47         None      None      1.0.0
# 60                1.0.0 2024-11-02 19:27:16         None      None      1.0.0
#
# [61 rows x 11 columns]
